# %%
# Uncomment this cell to run prompt optimization on a study. Most recent runs require running on a server.
# !uv run python -m syftr.prompt_optimization --study-config studies/rank1--rag-and-agents--drdocs_hf.yaml

# %%
# This cell takes two studies (witout PO and with it and compares the result). Please, note commented code:
# PO on studies/rank1--rag-and-agents--drdocs_hf.yaml weren't run on pareto, so we need all trials to perform a join, 
# not only Pareto trials.

import pandas as pd
import optuna
from syftr.optuna_helper import get_pareto_mask
from syftr.configuration import cfg

RAW_STUDY = "rank1--rag-and-agents--drdocs_hf"
PO_STUDY = "rank1--rag-and-agents--drdocs_hf_prompt_optimization"

df = optuna.load_study(
    study_name=RAW_STUDY, storage=cfg.database.get_optuna_storage()
).trials_dataframe()
# df = df[df["values_0"] > 0.5]
# pareto_mask = get_pareto_mask(df)
# df = df[get_pareto_mask]
df["study_name"] = RAW_STUDY

optimized_df = optuna.load_study(
    study_name=PO_STUDY, storage=cfg.database.get_optuna_storage()
).trials_dataframe()
optimized_df = optimized_df.drop_duplicates(
    subset=["user_attrs_parent_number"], keep="last"
)
optimized_df["study_name"] = PO_STUDY

results = pd.merge(
    df,
    optimized_df,
    left_on="number",
    right_on="user_attrs_parent_number",
)
results["Cost mult, x"] = results["values_1_y"] / results["values_1_x"]
results["Acc. improvement"] = (results["values_0_y"] - results["values_0_x"]) * 100
results = results.rename(
    columns={
        "values_0_x": "Accuracy pre-opt",
        "values_1_x": "Cost pre-opt",
        "values_0_y": "Accuracy post-opt",
        "values_1_y": "Cost post-opt",
    }
)
results["Accuracy pre-opt"] *= 100
results["Accuracy post-opt"] *= 100
results = results[
    [
        "Accuracy pre-opt",
        "Cost pre-opt",
        "Accuracy post-opt",
        "Cost post-opt",
        "Acc. improvement",
        "Cost mult, x",
        "user_attrs_flow_name",
        "user_attrs_parent_number",
    ]
]
results
# Out:
#    Accuracy pre-opt  Cost pre-opt  Accuracy post-opt  Cost post-opt  \
# 0         41.379310      0.000976          31.034483       0.000107
# 1         40.000000      0.000873          48.717949       0.000125
# 2         55.172414      0.001171          50.000000       0.000128
# 3         33.333333      0.000731           0.000000       0.001030
# 4         82.500000      0.005211          36.666667       0.001359
# 5         92.000000      0.011132          93.877551       0.009168
# 6         90.000000      0.010543          70.000000       0.003823
# 7         92.307692      0.017127          21.428571       0.002100
# 8         66.666667      0.004364          53.571429       0.005106
#
#    Acc. improvement  Cost mult, x user_attrs_flow_name  \
# 0        -10.344828      0.109949       ReActAgentFlow
# 1          8.717949      0.143424       ReActAgentFlow
# 2         -5.172414      0.109069       ReActAgentFlow
# 3        -33.333333      1.409807    CritiqueAgentFlow
# 4        -45.833333      0.260742   SubQuestionRAGFlow
# 5          1.877551      0.823559   SubQuestionRAGFlow
# 6        -20.000000      0.362654   SubQuestionRAGFlow
# 7        -70.879121      0.122607   SubQuestionRAGFlow
# 8        -13.095238      1.170131       ReActAgentFlow
#
#    user_attrs_parent_number
# 0                       121
# 1                       230
# 2                       269
# 3                       270
# 4                       505
# 5                       521
# 6                       596
# 7                       623
# 8                       626

# %%
optimized_df["user_attrs_optimized_dataset_description"].tolist()
# Out:
# ["The dataset describes specific aspects of DataRobot's services, including security features, explainability tools for AI, real-time scoring methods, integration guides, tutorials, setup documentation, multimodal modeling capabilities, hyperparameter tuning strategies, deployment methodologies, and troubleshooting practices. Utilize this context to provide comprehensive and detailed answers related to API endpoints, workflows, configurations, settings, and the nuances of DataRobot’s features. Ensure answers are complete, relevant, and specifically tailored to the queries posed.",
#  'The dataset is structured to optimize question answering by emphasizing clarity and precision. Annotated templates and key domain-specific procedures prioritize relevance and correctness, ensuring responses are aligned directly with user needs, without extraneous or irrelevant details.',
#  "Provide precise and user-scenario-specific guidance regarding DataRobot's features, integrations, and APIs, ensuring examples are both relevant and straightforward, avoiding unnecessary technical jargon or unrelated context.",
#  'Craft detailed and query-specific explanations tailored to practical applications of the DataRobot API and platform workflows, ensuring alignment with reference answers. Avoid generalizations, unrelated details, or incorrect terminology, focusing on targeted industry-specific insights that resolve user queries effectively and clearly.',
#  'Explicitly address automated machine learning, architecture optimization, and model management tools within DataRobot. Provide practical, step-by-step guidance tailored to these functionalities using clear examples and actionable methods. Avoid vague or verbose responses, ensuring alignment with user queries and maintaining accuracy and coherence throughout explanations.',
#  'The dataset contains contextually accurate information about DataRobot, focusing on API documentation and examples, setup guides, automated machine learning, deployment, integration, data handling practices, and model lifecycle management. Avoid extraneous details like Debugging Tips or Tutorials that do not relate to specific queries unless explicitly requested. Focus on foundational elements for DataRobot navigation.',
#  'Generate structured, accurate responses by thoroughly validating all methods, steps, and parameters systematically. Focus on factual consistency and alignment with user queries, removing ambiguities, redundancies, and inaccuracies. Ensure adherence to the context to optimize response alignment with expectations and utility.',
#  'The dataset is designed to offer targeted, user-focused solutions for utilizing DataRobot functionalities in real-world applications. It includes simplified step-by-step guides, practical use cases, and troubleshooting strategies covering model deployment, assessment, bias detection, monitoring, predictive analysis, and security—all presented with clear instructions to solve user-specific problems efficiently.',
#  'DataRobot tools empower users with cutting-edge automated machine learning capabilities, including comprehensive API usage guidance, deployment workflows, and model optimization strategies. Responses must integrate step-by-step instructions, complete configuration details, accurate endpoint URLs, visual aids, and critical feature flags for clarity. Address user queries with precision, relevance, and completeness, avoiding errors, generalized answers, or omissions of critical information.']
